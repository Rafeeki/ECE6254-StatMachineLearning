# %%
# Standard Library imports
# %matplotlib inline
import math, numpy
import matplotlib.pyplot as plt

# %%
# Initialize variables
ep = numpy.linspace(0,1,num=100)
P = numpy.zeros(100)
n = 10
m = 2
p = 0.5

# %%
# Calculate probability of empirical risk being ep[e] > given risk p
for e in range(0,len(ep)-1):
    P[e] = 2*m*math.exp(-2*n*ep[e]**2)
    #P[e] = 2*m*math.exp(-2/n*ep[e]**2)

# %%
# Final plot for 1b
plt.plot(ep,P)
plt.xlabel('Epsilon (risk tolerance)')
plt.ylabel('Probability')
plt.show()
# Need to show bound that results from applying the Hoeffding inequality with the union bound

# %%
# Problem 2d, need to adjust X for Z = max(X_i) for i = 1,...,m and X_1 ~ Normal(0,1)
B = [3, 4, 5, 6]
for b in B:
    m = 10**b
    X = numpy.zeros(m)
    for i in range(0,len(X)):
        x = numpy.random.randn(m)
        if x.max() > X.max(): X = x
    plt.hist(X)
    plt.title("Histogram of X with m = " + str(m))
    plt.show()

# %%
# Problem 3
x = numpy.linspace(0,10,100)
f_x = numpy.zeros(100)
for i in range(0,len(x)):
    f_x[i] = math.exp(-x[i])
plt.plot(x,f_x)
plt.show()

# %%
#Problem 4
# %run ./HW01_4.py
